# %%
import pandas as pd
import folium

# Load the CSV file into a DataFrame
locations_df = pd.read_csv("data/delhi_stations_info.csv")

# Create a folium map centered around the first location
map_center = [locations_df['latitude'].iloc[0], locations_df['longitude'].iloc[0]]
mymap = folium.Map(location=map_center, zoom_start=10)

# Add markers for each location
for index, row in locations_df.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['file_name']
    ).add_to(mymap)

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b9c32fafb33ec9dc1d1ff3329b072e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b9c32fafb33ec9dc1d1ff3329b072e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b9c32fafb33ec9dc1d1ff3329b072e7 = L.map(
#                 &quot;map_7b9c32fafb33ec9dc1d1ff3329b072e7&quot;,
#                 {
#                     center: [28.628624, 77.24106],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db20a23443e6eaf200a97c9358ad3f3c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_db20a23443e6eaf200a97c9358ad3f3c.addTo(map_7b9c32fafb33ec9dc1d1ff3329b072e7);
#
#             var marker_daa34be1bcbb9da18b1d3449ded4d7a7 = L.marker(
#                 [28.628624, 77.24106],
#                 {}
#             ).addTo(map_7b9c32fafb33ec9dc1d1ff3329b072e7);
#
#
#         var popup_c436aa68b329366c477d10c0661d42d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be7becd695607f9f3b90f42583e6a622 = $(`&lt;div id=&quot;html_be7becd695607f9f3b90f42583e6a622&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DL001&lt;/div&gt;`)[0];
#                 popup_c436aa68b329366c477d10c0661d42d9.setContent(html_be7becd695607f9f3b90f42583e6a622);
#
#
#
#         marker_daa34be1bcbb9da18b1d3449ded4d7a7.bindPopup(popup_c436aa68b329366c477d10c0661d42d9)
#         ;
#
#
#
#
#             var marker_8e40fbdfc05da07ac063d26e11a699b3 = L.marker(
#                 [28.6514781, 77.1473105],
#                 {}
#             ).addTo(map_7b9c32fafb33ec9dc1d1ff3329b072e7);
#
#
#         var popup_f63b90d7983e57ac0ad00d31a7708236 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e159a0b1a45af1565bf0d879ef826f3 = $(`&lt;div id=&quot;html_5e159a0b1a45af1565bf0d879ef826f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DL002&lt;/div&gt;`)[0];
#                 popup_f63b90d7983e57ac0ad00d31a7708236.setContent(html_5e159a0b1a45af1565bf0d879ef826f3);
#
#
#
#         marker_8e40fbdfc05da07ac063d26e11a699b3.bindPopup(popup_f63b90d7983e57ac0ad00d31a7708236)
#         ;
#
#
#
#
#             var marker_41dfb1ae191e541ef8a6363b1aed04fe = L.marker(
#                 [28.5504249, 77.2159377],
#                 {}
#             ).addTo(map_7b9c32fafb33ec9dc1d1ff3329b072e7);
#
#
#         var popup_0b9f3986a8f0d39ee00821ca9a9cc558 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fa6983ce5c6785fcfa9f431e992ac863 = $(`&lt;div id=&quot;html_fa6983ce5c6785fcfa9f431e992ac863&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DL003&lt;/div&gt;`)[0];
#                 popup_0b9f3986a8f0d39ee00821ca9a9cc558.setContent(html_fa6983ce5c6785fcfa9f431e992ac863);
#
#
#
#         marker_41dfb1ae191e541ef8a6363b1aed04fe.bindPopup(popup_0b9f3986a8f0d39ee00821ca9a9cc558)
#         ;
#
#
#
#
#             var marker_3c67f009673cb64e318696a8da89f18e = L.marker(
#                 [28.60909, 77.0325413],
#                 {}
#             ).addTo(map_7b9c32fafb33ec9dc1d1ff3329b072e7);
#
#
#         var popup_d7cc52c456cec35af3d4f2d9e6032b15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68496ddafd1b951c9111b654dbef2485 = $(`&lt;div id=&quot;html_68496ddafd1b951c9111b654dbef2485&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DL004&lt;/div&gt;`)[0];
#                 popup_d7cc52c456cec35af3d4f2d9e6032b15.setContent(html_68496ddafd1b951c9111b654dbef2485);
#
#
#
#         marker_3c67f009673cb64e318696a8da89f18e.bindPopup(popup_d7cc52c456cec35af3d4f2d9e6032b15)
#         ;
#
#
#
#
#             var marker_830bc67c5cab2e3b5cf6ae19ef671f03 = L.marker(
#                 [28.6811736, 77.3025234],
#                 {}
#             ).addTo(map_7b9c32fafb33ec9dc1d1ff3329b072e7);
#
#
#         var popup_a6d31c7e5585141ad58e5fa2c603d0bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f426114b43b1a4bd0a972dcfdb613651 = $(`&lt;div id=&quot;html_f426114b43b1a4bd0a972dcfdb613651&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DL005&lt;/div&gt;`)[0];
#                 popup_a6d31c7e5585141ad58e5fa2c603d0bc.setContent(html_f426114b43b1a4bd0a972dcfdb613651);
#
#
#
#         marker_830bc67c5cab2e3b5cf6ae19ef671f03.bindPopup(popup_a6d31c7e5585141ad58e5fa2c603d0bc)
#         ;
#
#
#
#
#             var marker_3c2b0eda49f1946c7cadbdc55abb78a4 = L.marker(
#                 [28.7500499

# %%
file_names = ["DL022", "DL038", "DL035", "DL024", "DL033", "DL007", "DL023", "DL031", "DL036", "DL014", "DL037", "DL040", "DL029", "DL039", "DL025", "DL019", "DL034", "DL028", "DL011", "DL016", "DL030", "DL004", "DL021", "DL026", "DL027"]

# Filter locations_df based on file_names
locations_df = locations_df[locations_df['file_name'].isin(file_names)]

# Create a folium map centered around the first location
map_center = [locations_df['latitude'].iloc[0], locations_df['longitude'].iloc[0]]
mymap = folium.Map(location=map_center, zoom_start=10)

# Add markers for each location
for index, row in locations_df.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['file_name']
    ).add_to(mymap)

# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd6342f0ff287a57887d0dfe0a778fd7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd6342f0ff287a57887d0dfe0a778fd7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd6342f0ff287a57887d0dfe0a778fd7 = L.map(
#                 &quot;map_fd6342f0ff287a57887d0dfe0a778fd7&quot;,
#                 {
#                     center: [28.60909, 77.0325413],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21bee2558bd378544ec5cf0f09307e42 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_21bee2558bd378544ec5cf0f09307e42.addTo(map_fd6342f0ff287a57887d0dfe0a778fd7);
#
#             var marker_1bb0a2eee7716f47e4be2fc299cbd94d = L.marker(
#                 [28.60909, 77.0325413],
#                 {}
#             ).addTo(map_fd6342f0ff287a57887d0dfe0a778fd7);
#
#
#         var popup_e74e81f7a5ba077adbcd1b04e0770934 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca6bffc82549ffc7a7976decf61f931e = $(`&lt;div id=&quot;html_ca6bffc82549ffc7a7976decf61f931e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DL004&lt;/div&gt;`)[0];
#                 popup_e74e81f7a5ba077adbcd1b04e0770934.setContent(html_ca6bffc82549ffc7a7976decf61f931e);
#
#
#
#         marker_1bb0a2eee7716f47e4be2fc299cbd94d.bindPopup(popup_e74e81f7a5ba077adbcd1b04e0770934)
#         ;
#
#
#
#
#             var marker_c5d0c2dada2b8f234907adbb637fb111 = L.marker(
#                 [28.7256504, 77.2011573],
#                 {}
#             ).addTo(map_fd6342f0ff287a57887d0dfe0a778fd7);
#
#
#         var popup_7f7ae8f493863ec3040bc878bf9cb008 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_557417e93f967a13304bb2f5e253e871 = $(`&lt;div id=&quot;html_557417e93f967a13304bb2f5e253e871&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DL007&lt;/div&gt;`)[0];
#                 popup_7f7ae8f493863ec3040bc878bf9cb008.setContent(html_557417e93f967a13304bb2f5e253e871);
#
#
#
#         marker_c5d0c2dada2b8f234907adbb637fb111.bindPopup(popup_7f7ae8f493863ec3040bc878bf9cb008)
#         ;
#
#
#
#
#             var marker_8b16d97fe89fd1843c04bbe1649ceee6 = L.marker(
#                 [28.4706914, 77.1099364],
#                 {}
#             ).addTo(map_fd6342f0ff287a57887d0dfe0a778fd7);
#
#
#         var popup_703c64e883504e791d8f7f720342986e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_07ce6b6f72d995ff02a1a1a7c7612a86 = $(`&lt;div id=&quot;html_07ce6b6f72d995ff02a1a1a7c7612a86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DL011&lt;/div&gt;`)[0];
#                 popup_703c64e883504e791d8f7f720342986e.setContent(html_07ce6b6f72d995ff02a1a1a7c7612a86);
#
#
#
#         marker_8b16d97fe89fd1843c04bbe1649ceee6.bindPopup(popup_703c64e883504e791d8f7f720342986e)
#         ;
#
#
#
#
#             var marker_9c50b0fd0205bf0a37ac7afc4ff228c8 = L.marker(
#                 [28.674045, 77.131023],
#                 {}
#             ).addTo(map_fd6342f0ff287a57887d0dfe0a778fd7);
#
#
#         var popup_fbbc9b8f93745d0c0c10789c59e6331d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d32a9b3ca1dfae1e7c46357e43da700e = $(`&lt;div id=&quot;html_d32a9b3ca1dfae1e7c46357e43da700e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DL014&lt;/div&gt;`)[0];
#                 popup_fbbc9b8f93745d0c0c10789c59e6331d.setContent(html_d32a9b3ca1dfae1e7c46357e43da700e);
#
#
#
#         marker_9c50b0fd0205bf0a37ac7afc4ff228c8.bindPopup(popup_fbbc9b8f93745d0c0c10789c59e6331d)
#         ;
#
#
#
#
#             var marker_78e8bd0242f7893adc7b7c858189dbb2 = L.marker(
#                 [28.5627763, 77.1180053],
#                 {}
#             ).addTo(map_fd6342f0ff287a57887d0dfe0a778fd7);
#
#
#         var popup_9e102a977f1fff9d4846002830899500 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_46677e2e18bf7b9bbffce4acd8175400 = $(`&lt;div id=&quot;html_46677e2e18bf7b9bbffce4acd8175400&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DL016&lt;/div&gt;`)[0];
#                 popup_9e102a977f1fff9d4846002830899500.setContent(html_46677e2e18bf7b9bbffce4acd8175400);
#
#
#
#         marker_78e8bd0242f7893adc7b7c858189dbb2.bindPopup(popup_9e102a977f1fff9d4846002830899500)
#         ;
#
#
#
#
#             var marker_e8376b7dbb3ad7e487dbef79d0d95277 = L.marker(
#                 [28.54239
